# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Effet de la bandwidth d'entrée
#
# (1) Nous avons étudié l'effet de la bandwidth du signal présenté en entrée dans le cas où les connexions du réseau, hormis les connexions entre la population source et la population E, sont désactivées. A présent, nous étudions son effet lorsque les poids synaptiques des connexions du ring sont homogènes.
#
# (2) Pour cela, nous paramétrons les connexions des quatres différentes projections de sorte qu'elles aient le même poids synaptique. Puis, une simulation du modèle est exécutée pour chaque valeur de bandwidth, et les rasterplots des trois populations sont alors générés.
#
# (3) Nous observons que....

# %% [markdown]
# ### Results

# %%
np.logspace(0, -4, 5, base=2)
# Out:
# array([ 1.    ,  0.5   ,  0.25  ,  0.125 ,  0.0625])

# %%
from RRNN import RRNN
import numpy as np
net = RRNN()
net.sim_params['w_exc_exc'] = net.w
net.sim_params['w_inh_inh'] = net.w
net.sim_params['w_exc_inh'] = net.w
s_ = net.variationRaster('b_input', 180*np.logspace(0, -4, 5, base=2))

# %%
from RRNN import RRNN
import numpy as np
for w in np.logspace(-1.6, -1.3, 5):
    print('-------- w = {} --------'.format(w))
    net = RRNN(w=w)
    net.sim_params['w_exc_exc'] = net.w
    net.sim_params['w_inh_inh'] = net.w
    net.sim_params['w_exc_inh'] = net.w
    net.sim_params['w_inh_exc'] = net.w
    _ = net.variationRaster('b_input', 180*np.logspace(0, -4, 5, base=2))
# Out:
# -------- w = 0.0251188643151 --------
# -------- w = 0.0298538261892 --------
# -------- w = 0.0354813389234 --------
# -------- w = 0.0421696503429 --------
# -------- w = 0.0501187233627 --------
