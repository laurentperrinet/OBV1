# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Effet des bandwidths des projections internes
#
# Après avoir étudié l'effet de la bandwidth de l'entrée sur un ring où les poids de toutes les connexions, sauf celles qui vont de la population source à la population excitatrice, sont identiques, nous cherchons maintenant à observer les effets d'une variation de bandwidth de chacune des quatre projections sur l'activité neuronale.
#
# Pour cela, nous fixons la bandwidth de l'entrée à 15° et nous générons des rasterplots pour chaque valeur de bandwidth d'une projection. Cette opération est répétée pour chacune des quatre projections.
#
# Nous constatons que, concernant l'activité des neurones de la population inhibitrice, seule une modification de la bandwidth pour la projection allant de la population excitatrice à la population inhibitrice (EI) a un effet sur le nombre de neurones actifs.

# %%
from RRNN import RRNN
net = RRNN(time=1000)
net.sim_params['b_input'] = 15
#net.sim_params['w_input_exc'] = 5.
#net.sim_params['input_rate'] = 50.
# Out:
# CSAConnector: libneurosim support not available in NEST.
# Falling back on PyNN's default CSAConnector.
# Please re-compile NEST using --with-libneurosim=PATH
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.

# %%
bw_values = 180*np.logspace(0, -4, 5, base=2)

# %%
net.variationRaster('b_exc_exc', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90     180.00        inf        inf        inf       15
# 1           90      90.00        inf        inf        inf       15
# 2           90      45.00        inf        inf        inf       15
# 3           90      22.50        inf        inf        inf       15
# 4           90      11.25        inf        inf        inf       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...      v_init_max  \
# 0      0.015      0.015      0.015      0.015     ...          -49.75
# 1      0.015      0.015      0.015      0.015     ...          -49.75
# 2      0.015      0.015      0.015      0.015     ...          -49.75
# 3      0.015      0.015      0.015      0.015     ...          -49.75
# 4      0.015      0.015      0.015      0.015     ...          -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        2.5          5        2.5
# 1       -53.5      -70     -60       -50        2.5          5        2.5
# 2       -53.5      -70     -60       -50        2.5          5        2.5
# 3       -53.5      -70     -60       -50        2.5          5        2.5
# 4       -53.5      -70     -60       -50        2.5          5        2.5
#
#    w_inh_inh w_input_exc
# 0          5         0.5
# 1          5         0.5
# 2          5         0.5
# 3          5         0.5
# 4          5         0.5
#
# [5 rows x 42 columns]

# %%
net.variationRaster('b_inh_exc', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90        inf        inf     180.00        inf       15
# 1           90        inf        inf      90.00        inf       15
# 2           90        inf        inf      45.00        inf       15
# 3           90        inf        inf      22.50        inf       15
# 4           90        inf        inf      11.25        inf       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...      v_init_max  \
# 0      0.015      0.015      0.015      0.015     ...          -49.75
# 1      0.015      0.015      0.015      0.015     ...          -49.75
# 2      0.015      0.015      0.015      0.015     ...          -49.75
# 3      0.015      0.015      0.015      0.015     ...          -49.75
# 4      0.015      0.015      0.015      0.015     ...          -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        2.5          5        2.5
# 1       -53.5      -70     -60       -50        2.5          5        2.5
# 2       -53.5      -70     -60       -50        2.5          5        2.5
# 3       -53.5      -70     -60       -50        2.5          5        2.5
# 4       -53.5      -70     -60       -50        2.5          5        2.5
#
#    w_inh_inh w_input_exc
# 0          5         0.5
# 1          5         0.5
# 2          5         0.5
# 3          5         0.5
# 4          5         0.5
#
# [5 rows x 42 columns]

# %%
net.variationRaster('b_inh_inh', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90        inf        inf        inf     180.00       15
# 1           90        inf        inf        inf      90.00       15
# 2           90        inf        inf        inf      45.00       15
# 3           90        inf        inf        inf      22.50       15
# 4           90        inf        inf        inf      11.25       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...      v_init_max  \
# 0      0.015      0.015      0.015      0.015     ...          -49.75
# 1      0.015      0.015      0.015      0.015     ...          -49.75
# 2      0.015      0.015      0.015      0.015     ...          -49.75
# 3      0.015      0.015      0.015      0.015     ...          -49.75
# 4      0.015      0.015      0.015      0.015     ...          -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        2.5          5        2.5
# 1       -53.5      -70     -60       -50        2.5          5        2.5
# 2       -53.5      -70     -60       -50        2.5          5        2.5
# 3       -53.5      -70     -60       -50        2.5          5        2.5
# 4       -53.5      -70     -60       -50        2.5          5        2.5
#
#    w_inh_inh w_input_exc
# 0          5         0.5
# 1          5         0.5
# 2          5         0.5
# 3          5         0.5
# 4          5         0.5
#
# [5 rows x 42 columns]

# %%
net.variationRaster('b_exc_inh', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90        inf     180.00        inf        inf       15
# 1           90        inf      90.00        inf        inf       15
# 2           90        inf      45.00        inf        inf       15
# 3           90        inf      22.50        inf        inf       15
# 4           90        inf      11.25        inf        inf       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...      v_init_max  \
# 0      0.015      0.015      0.015      0.015     ...          -49.75
# 1      0.015      0.015      0.015      0.015     ...          -49.75
# 2      0.015      0.015      0.015      0.015     ...          -49.75
# 3      0.015      0.015      0.015      0.015     ...          -49.75
# 4      0.015      0.015      0.015      0.015     ...          -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        2.5          5        2.5
# 1       -53.5      -70     -60       -50        2.5          5        2.5
# 2       -53.5      -70     -60       -50        2.5          5        2.5
# 3       -53.5      -70     -60       -50        2.5          5        2.5
# 4       -53.5      -70     -60       -50        2.5          5        2.5
#
#    w_inh_inh w_input_exc
# 0          5         0.5
# 1          5         0.5
# 2          5         0.5
# 3          5         0.5
# 4          5         0.5
#
# [5 rows x 42 columns]

# %% [markdown]
# ### si w=0 on devrait s'attendre à activité localisée dans E

# %%
net2 = RRNN(time=1000, w=0, w_in=0.005)
net2.sim_params['b_input'] = 45
df, sE, sI = net2.model()
net2.Raster(df, sE, sI, title='Ring')

# %% [markdown]
# Pourquoi le raster de E n'est-il pas "resseré"?

# %%
#net.variationRaster('b_input_exc', bw_values)
