# %% [markdown]
# # Plan du rapport
#
# ## Introduction
#
# ### Motivation
#
# Une entité ne peut être vivante si elle n'interagit pas avec son environnement. La vie, réduit à son plus simple appareil, comporte du code génétique. Pour se perpétuer, ce code génétique doit permettre de produire des molécules qui vont former le matériel nécessaire à sa protection, à son alimentation et enfin à sa reproduction. La cellule remplit ces rôles, aussi, sa membrane et les protéines qui la constituent lui permettent de jouer un rôle d'interface entre le code génétique et l'environnement. Il apparait que la notion d'interface soit importante dans le vivant. Ainsi, l'interface se conserve et se sophistique, au fil de nombreuses mutations du code génétique et de la sélection naturelle. Cette dernière va permettre l'émergence d'interfaces de plus en plus élaborées, qui vont offrir de multiples manières de filtrer l'environnement et des moyens d'explorer celui-ci.
#
# Avec l'apparition des organismes pluricellulaires et des moyens de communications entre les cellules, les cellules se spécialisent, s'assemblent et constituent des tissus cellulaires, des organes et des systèmes qui vont permettre à l'ensemble de l'organisme d'interagir, d'une manière spécifique au système considéré, avec l'environnement. Le système nerveux en est un exemple. En effet, celui-ci permet de traiter des informations externes ou internes, et une partie de ce traitement comprend diverses fonctions que l'on regroupe dans le concept de perception.
#
# Selon l'approche neurophysiologique de la vision, la perception visuelle est construite sur la photosensibilité de certaines cellules, les cônes et les bâtonnets. Ces cellules et d'autres comme, par exemple, les cellules ganglionnaires, forment la rétine tapissant le fond de l'oeil où, à tout instant, une image de l'environnement se projette. Les cellules photosensibles vont permettre d 'encoder les variations locales de luminosité composant l'image en variations de potentiel membranaire. Ces variations de potentiel vont ensuite être codées en influx nerveux qui vont être transmis dans le réseau rétinien pour y être transformés. Ce traitement permet la détection d'éléments locaux de l'image comme, par exemple, les bords et les couleurs. Une question se pose alors lorsqu'on cherche à associer le substrat biologique à la perception visuelle : comment le système nerveux central réalise l'intégration de ces éléments locaux afin de constuire un percept global ?
#
# Afin de répondre à cette large problématique, il convient de s'intéresser aux divers constituants de l'image espèce par espèce. Ainsi, le travail qui vous est présenté est dédié à l'étude de la détection d'orientations. Il s'incrit dans un projet interdisciplinaire porté par l'équipe Invibe au sein de l'Institut de Neurosciences de la Timone. Ce projet prévoit, outre (diverses investigations physiologiques?), une approche computationnelle des mécanismes impliqués dans cette détection d'orientations, qui constitue l'objet de ce travail.
#
# Cette approche...
#
# ### Annonce du plan
#
#
# ## Contexte scientifique
#
# Des électrophysiologistes tels que Hubel et Wiesel ont mis en évidence, chez le chat, que certains neurones du cortex visuel primaire ont une sensibilité préférentielle à une ou plusieurs orientations possibles de barres de contraste[]. L'avancée des études sur la détection d'orientations, conduisent à considérer le cortex visuel primaire comme une carte, où des zones regroupant des neurones de même sélectivité à l'orientation sont représentées[].
#
#
# ## Outils, méthodes et observations
#
#
# ### NN
#
# #### Plan
# #### spiking neuron
# #### RRNN
# #### Balanced States
#
# ### Ring
#
# #### Presentation
# #### Resultats
# #### OB V1
#
#
# ## Discussion
#
# #### Ce qui a été fait
#
# #### Predictions/limites
#
# #### Projet de thèse

# %% [markdown]
# Paramètres pour balanced states :
#
# * g = 4
# * w_in = 0.015
# * w = 0.04
# * s = 1
# * c = 0.015
# * p = 0.8
# * n = 1080

# %%
from IPython.display import FileLink, FileLinks
FileLinks('.')
# Out:
# ./
#   .DS_Store
#   2.1.1_NeuralNetworks_SpikingNeuronModel.ipynb
#   2.1.2_NeuralNetworks_Brian_OneNeuron.ipynb
#   2.1.3_NeuralNetworks_Brian.ipynb
#   2.1.4_NeuralNetworks_Nest.ipynb
#   2.1.5_NeuralNetworks_pyNN_CODAvsCUBA.ipynb
#   2.1.6_FeedForward_Exploration_I-Fcurve.ipynb
#   2.2.10_RRNN_Exploration_Curve_Sparseness.ipynb
#   2.2.11_RRNN_Exploration_Curve_G.ipynb
#   2.2.12_RRNN_Rasterplot_G.ipynb
#   2.2.1_RRNN_Presentation.ipynb
#   2.2.2_RRNN_Exploration_control cell parameters.ipynb
#   2.2.3_RRNN_Exploration_ModelExpVSAlpha.ipynb
#   2.2.4_RRNN_Rasterplot_InputVariation.ipynb
#   2.2.5_RRNN_Rasterplot_InputWeight.ipynb
#   2.2.6_RRNN_Exploration_I-Fcurve.ipynb
#   2.2.7_RRNN_Rasterplot_CheckingInvariants.ipynb
#   2.2.8_RRNN_Rasterplot_GlobalWeight_Variation.ipynb
#   2.2.9_RRNN_Exploration_Curve_Weights.ipynb
#   2.3.1_RRNN_BalancedStates_MultiOptimisation_Intro.ipynb
#   2.3.2_RRNN_BalancedStates_MultiOptimisation_DifferentWeight.ipynb
#   2.3.3_RRNN_BalancedStates_MultiOptimisation_DifferentG.ipynb
#   3.1.1_Ring Intro.ipynb
#   3.2.1_Ring Tuned input.ipynb
#   3.2.2_Ring Tuned input Homogeneous weight.ipynb
#   3.2.3_Ring Tuned_Bandwidths.ipynb
#   OO-2016-02-10_NeuralNetworks_Brian2 - TODO.ipynb
#   OO-2016-02-19_FeedForward.ipynb
#   OO-2016-03-02_FeedForward_ExpVSAlpha.ipynb
#   OO-2016-03-08_RRNN_Rasterplot_WeightVariation.ipynb
#   OO-2016-03-12_RRNN_Rasterplot_Sparseness_Variation.ipynb
#   OO-2016-04-23_RRNN_BalancedStates_MultiOptimisation_DifferentSparseness.ipynb
#   OO-2016-04-25_RRNN_BalancedStates_Rasterplot_EffectOfDeterministicInput.ipynb
#   OO-2016-05-13_Ring Tuned input Homogeneous weight_IFCurve.ipynb
#   OO-2016-05-18_Ring Tuned_FittingResponse.ipynb
#   Rapport_OB-V1.ipynb
#   RRNN.py
#   RRNN.pyc
#   XX-2016-02-23_FeedForward_Exploration.ipynb
#   XX-2016-03-30_RRNN_Rasterplot_Seeding.ipynb
#   XX-2016-04-04_RRNN_BalancedStates_Rasterplot_GVariation_Sparseness.ipynb
#   XX-2016-04-11_RRNN_BalancedStates_Rasterplot_Gvariation_OtherSparseness.ipynb
#   XX-2016-04-14_RRNN_BalancedStates_DeveloppingAnalysisTools.ipynb
#   XX-2016-04-15_RRNN_BalancedStates_dFoverdI.ipynb
#   XX-2016-04-19_RRNN_BalancedStates_CV.ipynb
#   XX-2016-04-20_RRNN_BalancedStates_MultiOptimisation.ipynb
#   XX-2016-04-20_RRNN_BalancedStates_Raster_SparsenessVariation.ipynb
#   XX-2016-04-29_RRNN_BalancedStates_Rasterplot_GandWeightVariation.ipynb
#   XX-2016-04-30_RRNN_BalancedStates_TuneInputWeight.ipynb
#   XX-2016-05-02_Ring Tuned input.ipynb
#   XX_2016-02-22_NeuralNetwork_ToSaveAnalyseData.ipynb
#   XX_2016-03-04_BalaV1_NeuralNetworks_Sparseness.ipynb
#   XX_2016-03-07_RRNN_Rasterplot.ipynb
#   XX_2016-03-11_RRNN_Rasterplot.ipynb
#   XX_2016-03-15_BalaV1_RRNN_Large_Rasterplot_10Hz.ipynb
#   XX_2016-03-21_RRNN_Rasterplot_WeightVariation.ipynb
#   XX_2016-03-24_RRNN_Rasterplot_InputVariation.ipynb
#   XX_2016-03-25_RRNN_Rasterplot_CheckingInvariants.ipynb
#   XX_2016-03-31_BalaV1_RRNN_Large_Rasterplot_WeightCoupleVariations.ipynb
#   XX_2016-03-XX_BalaV1_RRNN_Large_Rasterplot_WeightCoupleVariations.ipynb
#   XX_2016-04-02_RRNN_Rasterplot_Couplig_Variation_otherG.ipynb
#   XX_2016-04-22_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentWeight_WEJob-Copy3.ipynb
#   XX_2016-04-22_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentWeight_WEJob-Copy4.ipynb
#   XX_2016-04-22_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentWeight_WEJob.ipynb
#   XX_2016-04-22_BalaV1_RRNN_Large_Rasterplot_FindingBalancedStates_Raster.ipynb
#   XX_2016-04-25_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentWeight_WEJob-Timeit.ipynb
#   XX_2016-04-27_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentG_otherweighttest.ipynb
#   XX_2016-04-27_BalaV1_RandomRecurrentNeuralNetwork_FindingBalancedStates_MultiOptimisation_DifferentG_WeightVariation.ipynb
#   XX_2016-05-13_Ring_strtoVar.ipynb
# ./.ipynb_checkpoints/
#   2.1.1_NeuralNetworks_SpikingNeuronModel-checkpoint.ipynb
#   2.3.1_RRNN_BalancedStates_MultiOptimisation_Intro-checkpoint.ipynb
#   3.1.1_Ring Intro-checkpoint.ipynb
#   3.2.1_Ring Tuned input-checkpoint.ipynb
#   3.2.2_Ring Tuned input Homogeneous weight-checkpoint.ipynb
#   3.2.3_Ring Tuned_Bandwidths-checkpoint.ipynb
#   OO-2016-05-13_Ring Tuned input Homogeneous weight_IFCurve-checkpoint.ipynb
#   OO-2016-05-18_Ring Tuned_FittingResponse-checkpoint.ipynb
#   Rapport_OB-V1-checkpoint.ipynb
# ./data_RRNN/
#   b_input.pkl
