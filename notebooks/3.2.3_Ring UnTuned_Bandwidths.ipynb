# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from RRNN import RRNN

# %% [markdown]
# ### Effet des bandwidths des projections internes
#
# Après avoir étudié l'effet de la bandwidth de l'entrée sur un ring où les poids de toutes les connexions, sauf celles qui vont de la population source à la population excitatrice, sont identiques, nous cherchons maintenant à observer les effets d'une variation de bandwidth de chacune des quatre projections sur l'activité neuronale.
#
# Pour cela, nous fixons la bandwidth de l'entrée à 15° et nous générons des rasterplots pour chaque valeur de bandwidth d'une projection. Cette opération est répétée pour chacune des quatre projections.
#
# Nous constatons que, concernant l'activité des neurones de la population inhibitrice, seule une modification de la bandwidth pour la projection allant de la population excitatrice à la population inhibitrice (EI) a un effet sur le nombre de neurones actifs.

# %%
time=100
net = RRNN(time=time, b_input=15)
bw_values = 180*np.logspace(0, -4, 5, base=2)
net.variationRaster('b_exc_exc', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90     180.00         50         50          4       15
# 1           90      90.00         50         50          4       15
# 2           90      45.00         50         50          4       15
# 3           90      22.50         50         50          4       15
# 4           90      11.25         50         50          4       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.1        0.2        0.1
# 1       -53.5      -70     -60       -50        0.1        0.2        0.1
# 2       -53.5      -70     -60       -50        0.1        0.2        0.1
# 3       -53.5      -70     -60       -50        0.1        0.2        0.1
# 4       -53.5      -70     -60       -50        0.1        0.2        0.1
#
#    w_inh_inh  w_input_exc
# 0        0.2          0.5
# 1        0.2          0.5
# 2        0.2          0.5
# 3        0.2          0.5
# 4        0.2          0.5
#
# [5 rows x 43 columns]

# %%
net.variationRaster('b_inh_exc', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90          4         50     180.00          4       15
# 1           90          4         50      90.00          4       15
# 2           90          4         50      45.00          4       15
# 3           90          4         50      22.50          4       15
# 4           90          4         50      11.25          4       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.1        0.2        0.1
# 1       -53.5      -70     -60       -50        0.1        0.2        0.1
# 2       -53.5      -70     -60       -50        0.1        0.2        0.1
# 3       -53.5      -70     -60       -50        0.1        0.2        0.1
# 4       -53.5      -70     -60       -50        0.1        0.2        0.1
#
#    w_inh_inh  w_input_exc
# 0        0.2          0.5
# 1        0.2          0.5
# 2        0.2          0.5
# 3        0.2          0.5
# 4        0.2          0.5
#
# [5 rows x 43 columns]

# %%
net.variationRaster('b_inh_inh', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90          4         50         50     180.00       15
# 1           90          4         50         50      90.00       15
# 2           90          4         50         50      45.00       15
# 3           90          4         50         50      22.50       15
# 4           90          4         50         50      11.25       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.1        0.2        0.1
# 1       -53.5      -70     -60       -50        0.1        0.2        0.1
# 2       -53.5      -70     -60       -50        0.1        0.2        0.1
# 3       -53.5      -70     -60       -50        0.1        0.2        0.1
# 4       -53.5      -70     -60       -50        0.1        0.2        0.1
#
#    w_inh_inh  w_input_exc
# 0        0.2          0.5
# 1        0.2          0.5
# 2        0.2          0.5
# 3        0.2          0.5
# 4        0.2          0.5
#
# [5 rows x 43 columns]

# %%
net.variationRaster('b_exc_inh', bw_values)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90          4     180.00         50          4       15
# 1           90          4      90.00         50          4       15
# 2           90          4      45.00         50          4       15
# 3           90          4      22.50         50          4       15
# 4           90          4      11.25         50          4       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.1        0.2        0.1
# 1       -53.5      -70     -60       -50        0.1        0.2        0.1
# 2       -53.5      -70     -60       -50        0.1        0.2        0.1
# 3       -53.5      -70     -60       -50        0.1        0.2        0.1
# 4       -53.5      -70     -60       -50        0.1        0.2        0.1
#
#    w_inh_inh  w_input_exc
# 0        0.2          0.5
# 1        0.2          0.5
# 2        0.2          0.5
# 3        0.2          0.5
# 4        0.2          0.5
#
# [5 rows x 43 columns]
