# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Effet des bandwidths des projections internes
#
# Ici, nous étudions l'effet de variation des différentes largeurs de bande liées aux projections internes, c'est à dire les sélectivités à l'orientation associées aux différentes projections, sur la sélectivité du ring.
#
# D'une manière analogue aux études précedentes, nous exécutons une simulation pour chaque valeur de bandwidth. Nous générons alors, pour chaque simulation, les rasterplots des populations source, excitatrice et inhibitrice.

# %%
from RRNN import RRNN
from pyNN.utility.plotting import Figure, Panel
markersize = .5

time = 100
net = RRNN()

def rec_net(time=time, w=net.w, g=net.g, b_input=15, b_exc_inh=50, b_exc_exc=4, b_inh_exc=50, b_inh_inh=4):
    net = RRNN(time=time, w=w, g=g, c=1)
    net.sim_params['b_input'] = b_input
    net.sim_params['b_exc_inh'] = b_exc_inh
    net.sim_params['b_exc_exc'] = b_exc_exc
    net.sim_params['b_inh_exc'] = b_inh_exc
    net.sim_params['b_inh_inh'] = b_inh_inh
    return net

bw_values = 180*np.logspace(0, -4, 7, base=2)
# Out:
# CSAConnector: libneurosim support not available in NEST.
# Falling back on PyNN's default CSAConnector.
# Please re-compile NEST using --with-libneurosim=PATH

# %%
net = rec_net(time=time)
net.variationRaster('b_exc_exc', bw_values)
# Out:
#    angle_input   b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90  180.000000         50         50          4       15
# 1           90  113.392894         50         50          4       15
# 2           90   71.433047         50         50          4       15
# 3           90   45.000000         50         50          4       15
# 4           90   28.348224         50         50          4       15
# 5           90   17.858262         50         50          4       15
# 6           90   11.250000         50         50          4       15
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
# 5          1          1          1          1     ...           -49.75
# 6          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.1        0.2        0.1
# 1       -53.5      -70     -60       -50        0.1        0.2        0.1
# 2       -53.5      -70     -60       -50        0.1        0.2        0.1
# 3       -53.5      -70     -60       -50        0.1        0.2        0.1
# 4       -53.5      -70     -60       -50        0.1        0.2        0.1
# 5       -53.5      -70     -60       -50        0.1        0.2        0.1
# 6       -53.5      -70     -60       -50        0.1        0.2        0.1
#
#    w_inh_inh  w_input_exc
# 0        0.2          0.5
# 1        0.2          0.5
# 2        0.2          0.5
# 3        0.2          0.5
# 4        0.2          0.5
# 5        0.2          0.5
# 6        0.2          0.5
#
# [7 rows x 43 columns]

# %%
net = rec_net(time=time)
net.variationRaster('b_inh_exc', bw_values)

# %%
net = rec_net(time=time)
net.variationRaster('b_inh_inh', bw_values)

# %%
net = rec_net(time=time)
net.variationRaster('b_exc_inh', bw_values)
