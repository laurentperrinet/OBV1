# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from RRNN import RRNN
from pyNN.utility.plotting import Figure, Panel
# Out:
# CSAConnector: libneurosim support not available in NEST.
# Falling back on PyNN's default CSAConnector.
# Please re-compile NEST using --with-libneurosim=PATH

# %% [markdown]
# ### Effet des bandwidths des projections internes
#
# Ici, nous étudions l'effet de variation des différentes largeurs de bande liées aux projections internes, c'est à dire les sélectivités à l'orientation associées aux différentes projections, sur la sélectivité du ring.
#
# D'une manière analogue aux études précedentes, nous exécutons une simulation pour chaque valeur de bandwidth. Nous générons alors, pour chaque simulation, les rasterplots des populations source, excitatrice et inhibitrice.

# %%
bws = 180*np.logspace(0, -4, 7, base=2)

# %%
net = RRNN(ring=True, recurrent=True)
net.variationRaster('b_exc_exc', bws)
# Out:
#    angle_input   b_exc_exc  b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90  180.000000         50         50          4       10
# 1           90  113.392894         50         50          4       10
# 2           90   71.433047         50         50          4       10
# 3           90   45.000000         50         50          4       10
# 4           90   28.348224         50         50          4       10
# 5           90   17.858262         50         50          4       10
# 6           90   11.250000         50         50          4       10
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
# 5          1          1          1          1     ...           -49.75
# 6          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.5          1        0.5
# 1       -53.5      -70     -60       -50        0.5          1        0.5
# 2       -53.5      -70     -60       -50        0.5          1        0.5
# 3       -53.5      -70     -60       -50        0.5          1        0.5
# 4       -53.5      -70     -60       -50        0.5          1        0.5
# 5       -53.5      -70     -60       -50        0.5          1        0.5
# 6       -53.5      -70     -60       -50        0.5          1        0.5
#
#    w_inh_inh  w_input_exc
# 0          1          0.5
# 1          1          0.5
# 2          1          0.5
# 3          1          0.5
# 4          1          0.5
# 5          1          0.5
# 6          1          0.5
#
# [7 rows x 43 columns]

# %%
net = RRNN(ring=True, recurrent=True)
net.variationRaster('b_inh_exc', bws)
# Out:
#    angle_input  b_exc_exc  b_exc_inh   b_inh_exc  b_inh_inh  b_input  \
# 0           90          4         50  180.000000          4       10
# 1           90          4         50  113.392894          4       10
# 2           90          4         50   71.433047          4       10
# 3           90          4         50   45.000000          4       10
# 4           90          4         50   28.348224          4       10
# 5           90          4         50   17.858262          4       10
# 6           90          4         50   11.250000          4       10
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
# 5          1          1          1          1     ...           -49.75
# 6          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.5          1        0.5
# 1       -53.5      -70     -60       -50        0.5          1        0.5
# 2       -53.5      -70     -60       -50        0.5          1        0.5
# 3       -53.5      -70     -60       -50        0.5          1        0.5
# 4       -53.5      -70     -60       -50        0.5          1        0.5
# 5       -53.5      -70     -60       -50        0.5          1        0.5
# 6       -53.5      -70     -60       -50        0.5          1        0.5
#
#    w_inh_inh  w_input_exc
# 0          1          0.5
# 1          1          0.5
# 2          1          0.5
# 3          1          0.5
# 4          1          0.5
# 5          1          0.5
# 6          1          0.5
#
# [7 rows x 43 columns]

# %%
net = RRNN(ring=True, recurrent=True)
net.variationRaster('b_inh_inh', bws)
# Out:
#    angle_input  b_exc_exc  b_exc_inh  b_inh_exc   b_inh_inh  b_input  \
# 0           90          4         50         50  180.000000       10
# 1           90          4         50         50  113.392894       10
# 2           90          4         50         50   71.433047       10
# 3           90          4         50         50   45.000000       10
# 4           90          4         50         50   28.348224       10
# 5           90          4         50         50   17.858262       10
# 6           90          4         50         50   11.250000       10
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
# 5          1          1          1          1     ...           -49.75
# 6          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.5          1        0.5
# 1       -53.5      -70     -60       -50        0.5          1        0.5
# 2       -53.5      -70     -60       -50        0.5          1        0.5
# 3       -53.5      -70     -60       -50        0.5          1        0.5
# 4       -53.5      -70     -60       -50        0.5          1        0.5
# 5       -53.5      -70     -60       -50        0.5          1        0.5
# 6       -53.5      -70     -60       -50        0.5          1        0.5
#
#    w_inh_inh  w_input_exc
# 0          1          0.5
# 1          1          0.5
# 2          1          0.5
# 3          1          0.5
# 4          1          0.5
# 5          1          0.5
# 6          1          0.5
#
# [7 rows x 43 columns]

# %%
net = RRNN(ring=True, recurrent=True)
net.variationRaster('b_exc_inh', bws)
# Out:
#    angle_input  b_exc_exc   b_exc_inh  b_inh_exc  b_inh_inh  b_input  \
# 0           90          4  180.000000         50          4       10
# 1           90          4  113.392894         50          4       10
# 2           90          4   71.433047         50          4       10
# 3           90          4   45.000000         50          4       10
# 4           90          4   28.348224         50          4       10
# 5           90          4   17.858262         50          4       10
# 6           90          4   11.250000         50          4       10
#
#    c_exc_exc  c_exc_inh  c_inh_exc  c_inh_inh     ...       v_init_max  \
# 0          1          1          1          1     ...           -49.75
# 1          1          1          1          1     ...           -49.75
# 2          1          1          1          1     ...           -49.75
# 3          1          1          1          1     ...           -49.75
# 4          1          1          1          1     ...           -49.75
# 5          1          1          1          1     ...           -49.75
# 6          1          1          1          1     ...           -49.75
#
#    v_init_min  v_reset  v_rest  v_thresh  w_exc_exc  w_exc_inh  w_inh_exc  \
# 0       -53.5      -70     -60       -50        0.5          1        0.5
# 1       -53.5      -70     -60       -50        0.5          1        0.5
# 2       -53.5      -70     -60       -50        0.5          1        0.5
# 3       -53.5      -70     -60       -50        0.5          1        0.5
# 4       -53.5      -70     -60       -50        0.5          1        0.5
# 5       -53.5      -70     -60       -50        0.5          1        0.5
# 6       -53.5      -70     -60       -50        0.5          1        0.5
#
#    w_inh_inh  w_input_exc
# 0          1          0.5
# 1          1          0.5
# 2          1          0.5
# 3          1          0.5
# 4          1          0.5
# 5          1          0.5
# 6          1          0.5
#
# [7 rows x 43 columns]
