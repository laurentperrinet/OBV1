# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from RRNN import RRNN

# %%
net = RRNN(ring=False, recurrent= True)
net.w = 2.
net.g = 20.
#net.c = .15
net.init_params()
net.setParams(['p', 'N', 'i_rate', 'w_input_exc'],
              [.5, 1080, 10., 5.])

# %%
df, spikesE, spikesI = net.model()
f = net.Raster(df, spikesE, spikesI, title='RRNN in SI state')

# %%
f.fig.savefig('../figs/SI_RRNN.png', dpi = 600)
