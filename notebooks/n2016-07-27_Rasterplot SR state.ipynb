# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from RRNN import RRNN
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
net = RRNN(ring=False, recurrent= True)
net.w = 20
#net.g = 2.
#net.c = .15
net.init_params()
#net.setParams(['p', 'N', 'i_rate', 'w_input_exc'],
#              [.5, 1080,  10.,      5.])

# %%
df, spikesE, spikesI = net.model()
f = net.Raster(df, spikesE, spikesI, title='RRNN in SR state')

# %%
f.fig.savefig('../figs/SR_RRNN.png', dpi = 600)
