# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import numpy as np
from RRNN import RRNN
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Différences dans les courbes d'accord
#
# Par un ajustement de la distribution de Von Mises aux taux de décharge de la population excitatrice, nous tentons maintenant de montrer, de façon plus quantitative, l'effet de chacun des deux types de connectivité.
#
# Nous simulons donc le ring feed-forward et le ring récurrent avec différentes entrées, des distributions d'orientation ayant différentes largeurs de bande. Pour chacun des deux types de ring, nous mesurons le taux de décharge moyen de la population excitatrice et nous ajustons ensuite ces taux de décharge par des distributions de Von Mises.

# %%
net = RRNN(ring=True, recurrent=True)

# %%
net.sim_params['b_input']
# Out:
# 10.0

# %%
bw_values = 180*np.logspace(0, -4, 5, base=2)


for g in np.logspace(-1., 1., 9)*net.g:
    f, ax = plt.subplots()
    for bw_value in bw_values:
        net = RRNN(ring=True, recurrent=True)
        net.g = g
        net.init_params()
        net.sim_params['b_input'] = bw_value
        df, spikesE, spikesI = net.model()
        theta, fr, result = net.fit_vonMises(spikesE)
        #print(result.best_fit.mean())
        ax.plot(theta*180/np.pi, result.best_fit, label=str(bw_value))

    ax.set_xlabel('orientation')
    ax.set_ylabel('firing rate')
    ax.axis('tight')
    ax.set_ylim([0, 30])
    ax.set_title('g :{0}'.format(g))

    plt.legend(loc='best')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3d53ad8164e1> in <module>()
#       9         net.init_params()
#      10         net.sim_params['b_input'] = bw_value
# ---> 11         df, spikesE, spikesI = net.model()
#      12         theta, fr, result = net.fit_vonMises(spikesE)
#      13         #print(result.best_fit.mean())
#
# /Users/davidarbib/BalaV1/DetectingOrientations/da_OBV1/notebooks/RRNN.pyc in model(self, sim_index, sim_params, cell_params)
#     260             angle_post = 1. * np.arange(proj[conn_type].post.size)
#     261             w_ij = self.tuning_function(angle_pre[:, np.newaxis], angle_post[np.newaxis, :], bw, N_in)*weight
# --> 262             proj[conn_type].set(weight=w_ij)
#     263
#     264         # exc_inh = sim.Projection(E_neurons, I_neurons,
#
# /Users/davidarbib/Library/Python/2.7/lib/python/site-packages/pyNN/common/projections.pyc in set(self, **attributes)
#     157         # The plan is to add this option back at a later date.
#     158
# --> 159         attributes = self._value_list_to_array(attributes)
#     160         parameter_space = ParameterSpace(attributes,
#     161                                          self.synapse_type.get_schema(),
#
# /Users/davidarbib/Library/Python/2.7/lib/python/site-packages/pyNN/common/projections.pyc in _value_list_to_array(self, attributes)
#     168     def _value_list_to_array(self, attributes):
#     169         """Convert a list of connection parameters/attributes to a 2D array."""
# --> 170         connection_mask = ~numpy.isnan(self.get('weight', format='array', gather='all'))
#     171         for name, value in attributes.items():
#     172             if isinstance(value, list) or (isinstance(value, numpy.ndarray) and value.ndim == 1):
#
# /Users/davidarbib/Library/Python/2.7/lib/python/site-packages/pyNN/common/projections.pyc in get(self, attribute_names, format, gather, with_address)
#     290                         values[i][tmp_values[:, 0].astype(int), tmp_values[:, 1].astype(int)] = tmp_values[:, 2+i]
#     291             else:
# --> 292                 values = self._get_attributes_as_arrays(*attribute_names)
#     293             if return_single:
#     294                 if gather == 'all' or self._simulator.state.mpi_rank == 0:
#
# /Users/davidarbib/Library/Python/2.7/lib/python/site-packages/pyNN/nest/projections.pyc in _get_attributes_as_arrays(self, *names)
#     343                 # (offset is always 0,0 for connections created with connect())
#     344                 src, tgt, value = conn
# --> 345                 addr = self.pre.id_to_index(src), self.post.id_to_index(tgt)
#     346                 if numpy.isnan(value_arr[addr]):
#     347                     value_arr[addr] = value
#
# /Users/davidarbib/Library/Python/2.7/lib/python/site-packages/pyNN/common/populations.pyc in id_to_index(self, id)
#     666             >>> assert p.id_to_index(p[5]) == 5
#     667         """
# --> 668         if not numpy.iterable(id):
#     669             if not self.first_id <= id <= self.last_id:
#     670                 raise ValueError("id should be in the range [%d,%d], actually %d" % (self.first_id, self.last_id, id))
#
# KeyboardInterrupt:
